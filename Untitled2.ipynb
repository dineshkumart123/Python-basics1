# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshkumart123/Python-basics1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=int(input("enter your marks:"))

if marks>=50:
   print("you passed 12th 🤝")

else:
    print("come again next year 🖐️")
# Out:
# enter your marks:50
# you passed 12th 🤝

# %%
marks=int(input("enter your marks:"))

if marks>=50:
   print("you passed 12th 🤝")

else:
    print("come again next year 🖐️")
# Out:
# enter your marks:50
# you passed 12th 🤝
